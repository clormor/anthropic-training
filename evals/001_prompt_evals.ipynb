# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": A description of some solution criteria that could be used
        to grade the effectiveness of a solution e.g. runtime cost, memory cost, performance, readability etc.

    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Evaluation Criteria:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
from statistics import mean

def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
    """

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

def run_test_case(test_case):
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

def run_eval(dataset):
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Set\n\ndef extract_error_codes(logs_data: str) -> Set[str]:\n    \"\"\"\n    Extract unique error codes from CloudWatch Logs Insights query results.\n    Matches the pattern 'ERROR: [CODE]'\n    \"\"\"\n    pattern = r'ERROR:\\s*(\\S+)'\n    matches = re.findall(pattern, logs_data)\n    return set(matches)\n\nif __name__ == \"__main__\":\n    sample_logs = \"\"\"\n    2024-01-15 10:30:45 ERROR: E001 - Database connection failed\n    2024-01-15 10:31:12 ERROR: E002 - Invalid request format\n    2024-01-15 10:32:01 ERROR: E001 - Database timeout\n    2024-01-15 10:33:45 ERROR: E003 - Authentication failed\n    Some other log line without error\n    2024-01-15 10:34:20 ERROR: E002 - Request validation error\n    \"\"\"\n    \n    error_codes = extract_error_codes(sample_logs)\n    print(json.dumps(sorted(list(error_codes))))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch Logs Insights query result and extract all unique error codes from log messages matching the pattern 'ERROR: [CODE]'",
#       "format": "regex",
#       "solution_criteria": "Accuracy in capturing all error codes without false positives, ability to handle various error code formats (alphanumeric, with hyphens), and performance on large log datasets"
#     },
#     "score": 7.5,
#     "reasoning": "The solution works for the specific sample data provided but has critical limitations. The regex pattern is too simplistic and will capture unintended characters when error codes are followed by delimiters. It lacks robustness for actual CloudWatch Logs Insights JSON responses and missing input validation. For a production AWS solution, it needs to handle JSON parsing, stricter error code pattern definition, and graceful error handling."
#   },
#   {
#     "output": "\nimport boto3\nfrom datetime import timedelta\n\ndef get_presigned_url(bucket_name: str, object_key: str) -> str:\n    \"\"\"\n    Generate a pre-signed URL for an S3 object valid for 1 hour.\n    \n    Args:\n        bucket_name: The name of the S3 bucket\n        object_key: The key of the object in the bucket\n    \n    Returns:\n        A pre-signed URL string valid for 1 hour\n    \"\"\"\n    s3_client = boto3.client('s3')\n    \n    presigned_url = s3_client.generate_presigned_url(\n        'get_object',\n        Params={'Bucket': bucket_name, 'Key': object_key},\n        ExpiresIn=3600\n    )\n    \n    return presigned_url\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and object key, and returns a pre-signed URL valid for 1 hour using boto3",
#       "format": "python",
#       "solution_criteria": "Correct use of boto3 S3 client, proper expiration time setting (3600 seconds), error handling for invalid bucket/key, and code readability"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core requirement with proper boto3 syntax and expiration time. However, it lacks production-ready error handling and input validation that would prevent runtime failures. The unused import is a code quality issue. For a complete solution, the function should validate inputs and gracefully handle AWS service errors (e.g., NoSuchBucket, NoSuchKey, AccessDenied)."
#   },
#   {
#     "output": "\n{\n  \"LambdaExecutionRole\": {\n    \"Type\": \"AWS::IAM::Role\",\n    \"Properties\": {\n      \"AssumeRolePolicyDocument\": {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n          {\n            \"Effect\": \"Allow\",\n            \"Principal\": {\n              \"Service\": \"lambda.amazonaws.com\"\n            },\n            \"Action\": \"sts:AssumeRole\"\n          }\n        ]\n      },\n      \"ManagedPolicyArns\": [\n        \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n      ]\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda execution role with basic permissions to write logs to CloudWatch Logs",
#       "format": "json",
#       "solution_criteria": "Valid CloudFormation syntax, correct IAM policy structure, appropriate principle (Lambda service), minimal but sufficient permissions for CloudWatch Logs, and proper resource ARN formatting"
#     },
#     "score": 9.5,
#     "reasoning": "The solution correctly fulfills the core requirements with appropriate use of AWS managed policies rather than custom inline policies. The AssumeRolePolicyDocument is properly configured to allow the Lambda service to assume the role. The AWSLambdaBasicExecutionRole managed policy is the standard AWS approach for basic Lambda logging and is more maintainable than custom policies. Minor improvements around metadata (description, tags, name) would enhance production-readiness but do not affect functional correctness."
#   }
# ]
