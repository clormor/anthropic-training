# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (0.96.0)
# Requirement already satisfied: python-dotenv in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: sniffio in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: certifi in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/chris/git/anthropic-api/venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %% [markdown]
# # Helper function
#
# This function stores state in multi-turn conversations, allowing you to persist and send conversation history.
#
# This is critical, since the Anthropic API is entirely stateless.

# %%
def chat(messages, user_message):
    messages.append({"role": "user", "content": user_message})
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    response = message.content[0].text
    messages.append({"role": "assistant", "content": response})
    return response

# %% [markdown]
# # Chatbot
#
# Create a chatbot using a while True loop, which reads input from the user.

# %%
messages = []

while True:
    user_input = input("> ")

    if not user_input.strip():
        continue

    if user_input.strip().lower() == "quit":
        break

    answer = chat(messages, user_input)
    print("---")
    print("> ", answer)
    print("---")
