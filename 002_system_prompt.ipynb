# %%
# %pip install anthropic python-dotenv

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %% [markdown]
# # Helper function
#
# This function stores state in multi-turn conversations, allowing you to persist and send conversation history.
#
# This is critical, since the Anthropic API is entirely stateless.

# %%
def chat(messages, user_message):
    messages.append({"role": "user", "content": user_message})
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    text_block = next((b for b in message.content if b.type == "text"), None)
    if text_block is None:
        raise ValueError(f"No text block in API response: {message.content}")
    response = text_block.text
    messages.append({"role": "assistant", "content": response})
    return response

# %%
messages = []
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

answer = chat(messages, "How do I solve 5x + 2 = 3 for x", system=system_prompt)
print(answer)
# Out:
# Let's work through this step by step!
#
# The goal is to **get x by itself** on one side of the equation.
#
# **Step 1:** Look at the equation: `5x + 2 = 3`
#
# Right now, there's a **+2** on the same side as x. What could you do to both sides of the equation to start getting rid of that +2?
